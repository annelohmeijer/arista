# %% [markdown]
# ## Market signals exploration notebook

# %% [markdown]
# Elke tabel in de database die gevuld wordt door de pipelines vertaalt naar een repository. Dus
# data uit de tabel `deribit_futures` kun je ophalen via repository `DeribitFutureRepository`:
# ```
# DeribitFutureRepository
# FundingRateRepository
# CoinmarketcapRepository
# OpenInterestRepository
# ```

# %%
# auto reload module

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

from arista import models

# %%
help(models.DeribitFuturesRepository)
# Out:
# Help on class DeribitFuturesRepository in module arista.models.deribit:
#
# class DeribitFuturesRepository(arista.db.repositories.BaseRepository)
#  |  Repository to interact with Deribit Futures table.
#  |
#  |  Method resolution order:
#  |      DeribitFuturesRepository
#  |      arista.db.repositories.BaseRepository
#  |      typing.Generic
#  |      builtins.object
#  |
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {}
#  |
#  |  __orig_bases__ = (arista.db.repositories.BaseRepository[arista.models....
#  |
#  |  __parameters__ = ()
#  |
#  |  timestamp_col = 'unix_timestamp'
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from arista.db.repositories.BaseRepository:
#  |
#  |  __init__(self)
#  |      Initialize the repository with a database session.
#  |
#  |  bulk_create(self, objs: list[~Model])
#  |      Create multiple objects in the table.
#  |
#  |  create(self, obj: ~Model) -> ~Model
# ...

# %% [markdown]
# ### Alle data uit tabel naar Pandas Dataframe
#
# In principe alleen method nodig om alles in te lezen naar Pandas dataframe

# %%
df_deribit_futures = models.DeribitFuturesRepository().read_all(as_df = True)

# %%
df_deribit_futures
# Out:
#           price     instrument future_reference           datetime_     id  \
# 0      73418.00  BTC-PERPETUAL        perpetual 2024-11-06 00:00:00   2354
# 1       2593.25  ETH-PERPETUAL        perpetual 2024-11-06 00:00:00   2355
# 2      68936.00  BTC-PERPETUAL        perpetual 2024-11-05 00:00:00   2356
# 3       2440.40  ETH-PERPETUAL        perpetual 2024-11-05 00:00:00   2357
# 4      68649.50  BTC-PERPETUAL        perpetual 2024-11-04 00:00:00   2358
# ...         ...            ...              ...                 ...    ...
# 14921   3317.50    ETH-28MAR25  current_quarter 2025-01-31 06:00:00  15930
# 14922   3384.25    ETH-27JUN25        quarter_1 2025-01-31 06:00:00  15931
# 14923   2906.75    ETH-26SEP25        quarter_2 2025-01-31 06:00:00  15932
# 14924   2884.00    ETH-26DEC25        quarter_3 2025-01-31 06:00:00  15933
# 14925   3146.10  ETH-PERPETUAL        perpetual 2025-01-31 06:00:00  15934
#
#       expiration asset  unix_timestamp  size
# ...

# %%
# here magic AI stuff
